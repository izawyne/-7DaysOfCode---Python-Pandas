# %% [markdown]
# # #7DaysOfCode - Python Pandas 1/7: Importação de dados

# %%
# Importar as bibliotecas 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# Out:
# C:\Users\Izabella\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Gerar as variáveis
base = "dados_20"
number1 = range(10, 21)
number2 = [1,2]

# Criar um dicionário para armazenar as variáveis
variables = {} # key: value

# Gerar e armazenar as variáveis no dicionário
for num1 in number1:
    for num2 in number2:
        key = f"{base}{num1}_{num2}"
        variables[key] = f"pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20{num1}{num2}.csv?raw=true')"
        
# Acessar e usar as variáveis
for key, value in variables.items():
    print(f"{key} = {value}")
# Out:
# dados_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
# dados_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
# dados_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
# dados_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
# dados_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
# ...

# %%
# Variables
dados_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %%
# Mesclar/concatenar os dados

emprestimos_bibli = pd.concat([dados_2010_1, dados_2010_2, dados_2011_1, dados_2011_2, dados_2012_1, dados_2012_2, dados_2013_1, dados_2013_2, dados_2014_1, dados_2014_2, dados_2015_1, dados_2015_2, dados_2016_1, dados_2016_2, dados_2017_1, dados_2017_2, dados_2018_1, dados_2018_2, dados_2019_1, dados_2019_2, dados_2020_1])

# %%
# Visualizar as primeiras linhas do banco de dados
emprestimos_bibli.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %%
# Verificar o formato do banco de dados
emprestimos_bibli.shape
# Out:
# (2258018, 7)

# %%
# Identificação dos rótulos das colunas do banco de dados
emprestimos_bibli.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario'],
#       dtype='object')

# %%
# Obter uma descrição resumida sobre o banco de dados
emprestimos_bibli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258018 entries, 0 to 26560
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 137.8+ MB

# %%
# Obter uma descrição resumida sobre o banco de dados
emprestimos_bibli.describe()
# Out:
#        id_emprestimo  matricula_ou_siape
# count   2.258018e+06        2.254848e+06
# mean    2.617069e+06        6.127611e+09
# std     2.517077e+06        7.827175e+09
# min     7.096840e+05        0.000000e+00
# 25%     1.288985e+06        2.010057e+09
# 50%     1.854210e+06        2.012975e+09
# 75%     2.653337e+06        2.016069e+09
# max     1.032233e+07        2.022301e+10

# %%
# Verificar se há duplicatas
emprestimos_bibli.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %%
# Excluir duplicatas
emprestimos_bibli = emprestimos_bibli.drop_duplicates()

# %%
emprestimos_bibli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2257981 entries, 0 to 26560
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 137.8+ MB

# %%
# Importando o restante dos dados
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')

# %%
# Visualizar as primeiras linhas dos dados exemplares
dados_exemplares.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
dados_exemplares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546237 entries, 0 to 568584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_exemplar       546237 non-null  int64
#  1   codigo_barras     546237 non-null  object
#  2   colecao           546237 non-null  object
#  3   biblioteca        546237 non-null  object
#  4   status_material   546237 non-null  object
#  5   localizacao       546237 non-null  int64
#  6   registro_sistema  546237 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 33.3+ MB

# %%
# Unir os DataFrames
df_completo = emprestimos_bibli.merge(dados_exemplares)

# %%
df_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
# Visualizar as colunas
df_completo.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'registro_sistema'],
#       dtype='object')

# %%
# Examinar os dados
df_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 205.6+ MB

# %% [markdown]
# # #7DaysOfCode - Python Pandas 2/7: Limpeza de dados

# %% [markdown]
# #### Os itens do acervo em uma biblioteca são organizados por um sistema de classificação de acordo com o respectivo tema. Existem diversos sistemas, mas este conjunto está de acordo com a CDU - Classificação Decimal Universal. Esta classificação é decimal, pois varia de acordo com a classe de cada assunto
#
# 000 a 099: Generalidades. Ciência e conhecimento.
#
# 100 a 199: Filosofia e psicologia.
#
# 200 a 299: Religião.
#
# 300 a 399: Ciências sociais.
#
# 400 a 499: Classe vaga. Provisoriamente não ocupada.
#
# 500 a 599: Matemática e ciências naturais.
#
# 600 a 699: Ciências aplicadas.
#
# 700 a 799: Belas artes.
# 800 a 899: Linguagem. Língua. Linguística.
#
# 900 a 999: Geografia. Biografia. História.

# %%
# Atribuir a classificação para a localização

# Definindo os intervalos e rotulos

bins = (0, 100, 200, 300, 400, 500, 600, 700, 800, 900, float('inf'))
labels = ('Generalidades','Filosofia e psicologia','Religiao', 'Ciencias sociais','Classe vaga',
          'Matematica e ciencias neurais','Ciencias aplicadas','Belas artes', 'Linguagem',
          'Geografia. Biografia. Historia')

# Utilizar a funcao pd.cut() para criar as categorias
df_completo['CDU_categoria'] = pd.cut(df_completo['localizacao'], bins=bins, labels=labels, right=False)

df_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
# Excluir coluna registro_sistema
df_completo.drop(columns=['registro_sistema'], inplace=True)

# %%
# Verificar se a coluna foi dropada
df_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
# Converter a coluna matricula_ou_siape para string
df_completo['matricula_ou_siape'] = df_completo['matricula_ou_siape'].astype(str)

# %%
df_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
df_completo.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1162077
# data_emprestimo               0
# data_devolucao             6178
# matricula_ou_siape            0
# tipo_vinculo_usuario          0
# id_exemplar                   0
# colecao                       0
# biblioteca                    0
# status_material               0
# localizacao                   0
# CDU_categoria                 0
# dtype: int64

# %%
# Dropar a coluna data_renovacao
df_completo.drop(columns=['data_renovacao'], inplace=True)

df_completo.head()
# Out:
#    id_emprestimo codigo_barras                data_emprestimo  \
# 0         709684       L095049  2010/01/04 07:44:10.721000000
# 1         709685       L167050  2010/01/04 07:44:10.750000000
# 2         709686    2006017618  2010/01/04 08:08:44.081000000
# 3         709687       L184117  2010/01/04 08:24:21.284000000
# 4         709688    2007027500  2010/01/04 08:27:33.569000000
#
#                   data_devolucao matricula_ou_siape    tipo_vinculo_usuario  \
# 0  2010/01/05 16:26:12.662000000       2008023265.0      ALUNO DE GRADUAÇÃO
# 1  2010/01/12 07:34:13.934000000       2008023265.0      ALUNO DE GRADUAÇÃO
# 2  2010/02/25 07:36:25.800000000       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 3  2010/02/03 08:58:45.692000000        200721119.0      ALUNO DE GRADUAÇÃO
# 4  2010/02/03 13:06:30.662000000       2009045971.0      ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao  \
# 0        13259  Acervo Circulante
# 1        70865  Acervo Circulante
# ...

# %%
df_completo.isnull().sum()
# Out:
# id_emprestimo              0
# codigo_barras              0
# data_emprestimo            0
# data_devolucao          6178
# matricula_ou_siape         0
# tipo_vinculo_usuario       0
# id_exemplar                0
# colecao                    0
# biblioteca                 0
# status_material            0
# localizacao                0
# CDU_categoria              0
# dtype: int64

# %% [markdown]
# # #7DaysOfCode - Python Pandas 3/7: Análise exploratória de dados e DateTime

# %%
# Verificar a relacao entre emprestimo e emprestimo de exemplar

df_completo['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 2772079     3
# 2010326     3
# 2014596     3
# 10240112    3
# 2595954     3
#            ..
# 1523986     1
# 1523984     1
# 1523983     1
# 1523981     1
# 2989090     1
# Name: count, Length: 2068724, dtype: int64

# %%
df_completo.loc[df_completo['id_emprestimo'] == 2014596]
# Out:
#          id_emprestimo codigo_barras                data_emprestimo  \
# 1145827        2014596    2010082016  2015/06/10 18:51:56.994000000
# 1145828        2014596    2010082016  2015/06/10 18:51:56.994000000
# 1145829        2014596    2010082016  2015/06/10 18:51:56.994000000
#
#                         data_devolucao matricula_ou_siape  \
# 1145827  2015/06/22 15:06:49.000000000        198704783.0
# 1145828  2015/06/22 15:06:49.000000000        198704783.0
# 1145829  2015/06/22 15:06:49.000000000        198704783.0
#
#         tipo_vinculo_usuario  id_exemplar            colecao  \
# 1145827              DOCENTE      1055570  Acervo Circulante
# 1145828              DOCENTE      1055922  Acervo Circulante
# 1145829              DOCENTE      1056360  Acervo Circulante
#
#                              biblioteca status_material  localizacao  \
# 1145827  Biblioteca Central Zila Mamede         REGULAR          670
# ...

# %% [markdown]
# #### Cada emprestimo equivale a diferentes exemplares. Portanto, cada linha representa um exemplar o qual foi emprestado.

# %%
# Quantos emprestimos foram realizados no total?
emprestimos = len(df_completo['id_emprestimo'].drop_duplicates())
emprestimos
# Out:
# 2068724

# %%
# Quantos exemplares foram emprestados no total?

df_completo['id_emprestimo'].value_counts().sum()
# Out:
# 2072522

# %%
# Quantidade de exemplares emprestados por ano
emprestimo_data = pd.DataFrame(df_completo['data_emprestimo'].value_counts()).reset_index() 
emprestimo_data.columns = ['data', 'quantidade']

"""O .reset_index() é necessário para transformar o índice em uma coluna e 
facilitar o acesso e manipulação dos dados no DataFrame."""

# Transformar as datas para Datatime
emprestimo_data['data'] = pd.to_datetime(emprestimo_data['data'])
emprestimo_data
# Out:
#                            data  quantidade
# 0       2015-06-10 18:51:56.994           3
# 1       2018-02-22 10:45:11.523           3
# 2       2014-01-28 14:49:50.505           3
# 3       2015-08-18 19:11:08.653           3
# 4       2014-07-14 15:35:51.822           3
# ...                         ...         ...
# 2068686 2013-06-06 17:41:22.688           1
# 2068687 2013-06-06 17:40:06.074           1
# 2068688 2013-06-06 17:39:44.209           1
# 2068689 2013-06-06 17:34:42.071           1
# 2068690 2020-06-09 11:54:02.852           1
#
# [2068691 rows x 2 columns]

# %%
# Quantidade de emprestimos por ano

# Transformar 'data_emprestimo' para datetime
df_completo['data_emprestimo'] = pd.to_datetime(df_completo['data_emprestimo'])

# Extrair somente o ano da coluna de data
df_completo['ano_emprestimo'] = df_completo['data_emprestimo'].dt.year

# Contar quantos emprestimos foram feitos
emprestimo_ano = df_completo['ano_emprestimo'].value_counts()

# Emprestimo por ordem crescente
emprestimo_ano = emprestimo_ano.sort_index()
emprestimo_ano
# Out:
# ano_emprestimo
# 2010    161394
# 2011    196390
# 2012    221365
# 2013    234749
# 2014    219189
# 2015    213582
# 2016    215900
# 2017    218462
# 2018    194080
# 2019    171801
# 2020     25610
# Name: count, dtype: int64

# %%
# Visualizacao de forma grafica

emprestimo_ano.plot(kind='line', marker='o', linestyle='-')

plt.title('Quantidade de emprestimos por ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade')

plt.grid(True)
plt.show()

# %% [markdown]
# #### 1.A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?
#
# A quantidade de emprestimos aumento entre 2012 a 2013 de 2014 a 2017 teve um leve aumento porem a partir de 2017 os emprestimos cairam consideravelmente.
#
# E importante que a biblioteca avalie o porque do decaimento apos o ano de 2013:
# * O numero de alunos da faculdade diminuiu?
# * Como esta a pesquisa de satisfacao dos usuarios da biblioteca?
# * O acervo esta atualizado?
# * Quais sao as estrategias de marketing que a biblioteca esta realizando?
# * O que ocorreu de diferente em 2017 em relacao aos 2 anos antecedentes?
# * E o que ocorreu em 2019?
# * A queda em 2020 pode ter sido pela pandemia? Pq estava tudo fechado e não tinha como ir ao local para realizar o emprestimo?
# * Seria interessante realizar a análise dos próximos 2 ou 3 anos, para entender se continuou com a queda ou teve aumento nos emprestimos.

# %%
# Quantidade de exemplares emprestados por mes

# Extrair somente o mês da coluna de data
df_completo['mes_emprestimo'] = df_completo['data_emprestimo'].dt.month_name() #dt.month_name() para ter os nomes dos meses

# Contar quantos emprestimos foram feitos
emprestimo_mes = df_completo['mes_emprestimo'].value_counts()

# Ordenar por meses
ordem_meses = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 
               'August', 'September', 'October', 'November', 'December']

emprestimo_mes = emprestimo_mes.reindex(ordem_meses)
emprestimo_mes
# Out:
# mes_emprestimo
# January       67514
# February     210200
# March        252185
# April        208725
# May          202530
# June         138123
# July         123790
# August       232793
# September    208234
# October      188410
# November     164222
# December      75796
# Name: count, dtype: int64

# %%
# Visualizacao de forma grafica

emprestimo_mes.plot(kind='line', marker='o', linestyle='-')

plt.title('Quantidade de emprestimos por mes')
plt.xlabel('Mes')
plt.ylabel('Quantidade')

plt.grid(True)
plt.show()

# %% [markdown]
# Os meses com maiores quantidades de emprestimos foram os meses de marco e agosto.
#
# Os meses de ferias (janeiro, julho e dezembro) são os meses com a menor quantidade de emprestimos.
#
# No mes de junho tem uma consideravel queda, e importante pesquisar e entender o pq tem essa queda e o que pode ser feito para aumentar os emprestimos em junho.
#
# Os meses para se atentar e realizar mais marketing para aumentar o número de exemplares emprestados são os meses de abril, maio, setembro e outubro. A biblioteca deve olhar mais para esses meses e realizar um plano para aumento dos emprestimos.

# %%
# Quantidade de exemplares emprestados por hora

# Extrair somente o horário da coluna de data
df_completo['hora_emprestimo'] = df_completo['data_emprestimo'].dt.hour

# Contar quantos emprestimos foram feitos
emprestimo_hora = df_completo['hora_emprestimo'].value_counts()

# Emprestimo por ordem crescente
emprestimo_hora = emprestimo_hora.sort_index()
emprestimo_hora
# Out:
# hora_emprestimo
# 0         17
# 6         14
# 7      18777
# 8     103416
# 9     131273
# 10    185839
# 11    180048
# 12    148754
# 13    126987
# 14    150876
# 15    166672
# 16    210655
# 17    185340
# 18    182520
# 19    102129
# 20    127716
# 21     51191
# 22       247
# 23        51
# Name: count, dtype: int64

# %%
# Visualizacao de forma grafica

plt.figure(figsize=(12,6))

emprestimo_hora.plot(kind='bar', color='skyblue')

plt.title('Quantidade de emprestimos por hora')
plt.xlabel('Hora')
plt.ylabel('Quantidade')
plt.grid(False)

# Para deixar os rótulos do eixo X na horizontal
plt.xticks(rotation=0)


plt.show()

# %% [markdown]
# Através do gráfico é possível observar que os horários com maior pico de emprestimos acontecem entre 10h e 16h. No horário das 13h há uma queda, mas pode ser por conta do horário de almoço.
#
# Os melhores horários para alocar as demais atividades que não sejam de atendimento ao usuário são entre 7h e 9h e das 19h às 21h.

# %% [markdown]
# # #7DaysOfCode - Python Pandas 4/7: Análise exploratória de dados e Variáveis categóricas

# %% [markdown]
# ##### Vamos explorar algumas das variáveis categóricas das quais precisaremos extrair mais informações. Elas são:
#
#
# * Tipo de vínculo
# * Coleção
# * Biblioteca
# * Classificação geral da CDU
#
# ##### Para explorar os dados, alguns questionamentos serão pertinentes para a diretoria das bibliotecas, como:
#
# * “Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?”
# Desta forma, a diretoria poderá entender qual é o público que está utilizando a biblioteca e assim tomar decisões em continuar com a estratégia de negócio atual ou modificá-la.
#
# * Quais coleções são mais emprestadas?
# Da mesma forma, as coleções. Ranquear as coleções mais emprestadas pelo público, será bastante importante para a estratégia atual.
#
# * Quais são as bibliotecas com mais ou menos quantidade de empréstimos?
# Assim, a diretoria conseguirá entender onde ela deverá melhorar e focar suas iniciativas.
#
# * De quais temas da CDU são os exemplares emprestados?

# %%
# Imprimir a tabela para visualização
df_completo.head()
# Out:
#    id_emprestimo codigo_barras         data_emprestimo  \
# 0         709684       L095049 2010-01-04 07:44:10.721
# 1         709685       L167050 2010-01-04 07:44:10.750
# 2         709686    2006017618 2010-01-04 08:08:44.081
# 3         709687       L184117 2010-01-04 08:24:21.284
# 4         709688    2007027500 2010-01-04 08:27:33.569
#
#                   data_devolucao matricula_ou_siape    tipo_vinculo_usuario  \
# 0  2010/01/05 16:26:12.662000000       2008023265.0      ALUNO DE GRADUAÇÃO
# 1  2010/01/12 07:34:13.934000000       2008023265.0      ALUNO DE GRADUAÇÃO
# 2  2010/02/25 07:36:25.800000000       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 3  2010/02/03 08:58:45.692000000        200721119.0      ALUNO DE GRADUAÇÃO
# 4  2010/02/03 13:06:30.662000000       2009045971.0      ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao  \
# 0        13259  Acervo Circulante
# 1        70865  Acervo Circulante
# 2       195347  Acervo Circulante
# ...

# %%
# Analisar os valores únicos das colunas necessárias para as análises

# Tipo de vinculo do usuario
vinculo_usuario = df_completo['tipo_vinculo_usuario'].unique()
vinculo_usuario
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'SERVIDOR TÉCNICO-ADMINISTRATIVO', 'DOCENTE EXTERNO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
# Tipo de colecao
colecao = df_completo['colecao'].unique()
colecao
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
# Nomes das bibliotecas
biblioteca = df_completo['biblioteca'].unique()
biblioteca
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...

# %%
# Classificacao geral da CDU
CDU_noms = df_completo['CDU_categoria'].unique()
CDU_noms
# Out:
# ['Ciencias aplicadas', 'Linguagem', 'Ciencias sociais', 'Geografia. Biografia. Historia', 'Matematica e ciencias neurais', 'Religiao', 'Generalidades', 'Filosofia e psicologia', 'Belas artes']
# Categories (10, object): ['Generalidades' < 'Filosofia e psicologia' < 'Religiao' < 'Ciencias sociais' ... 'Ciencias aplicadas' < 'Belas artes' < 'Linguagem' < 'Geografia. Biografia. Historia']

# %%
# Funcao

def tabela_freq(variavel):
    """Objetivo da funcao e gerar uma tabela de frequencia com percentuais
    de acordo com a variavel passada.
    
    variavel = variavel categoria escolhida de dentro do conjunto de dados"""
    
    df = pd.DataFrame(df_completo[variavel].value_counts())
    df.columns = ['quantidade']
    df['percentual'] = round((df.quantidade / df.quantidade.sum())*100,1)
    
    return df

# %% [markdown]
# ### Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?

# %%
tabela_freq('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324        77.8
# ALUNO DE PÓS-GRADUAÇÃO               302541        14.6
# DOCENTE                               70981         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184         1.6
# ALUNO MÉDIO/TÉCNICO                   28029         1.4
# DOCENTE EXTERNO                       23949         1.2
# USUÁRIO EXTERNO                        2509         0.1
# OUTROS                                    5         0.0

# %% [markdown]
# De acordo com as tabelas geradas, e possivel observar que os alunos de Graduacao sao os que mais pegam livros emprestados, apresentando cerca de 78% dos vinculos, seguido pelos alunos de pos graduacao com aproximadamte 15%. Portanto, e importante verificar o pq dos outros vinculos nao pegarem emprestado tantos livros, pode ser por causa da quantidade de alunos? Ou por nao ter livros nas bibliotecas para alunos de outros vinculos?

# %% [markdown]
# ### Quais coleções são mais emprestadas?

# %%
tabela_freq('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                         2053120        99.1
# Multimeios                                   7954         0.4
# Monografias                                  4021         0.2
# Dissertações                                 2406         0.1
# Obras de Referência                          1954         0.1
# Publicações de Autores do RN                  866         0.0
# Publicações da UFRN                           764         0.0
# Teses                                         714         0.0
# Folhetos                                      271         0.0
# Necessidades Educacionais Específicas         130         0.0
# Trabalho Acadêmico                            115         0.0
# Eventos                                       101         0.0
# Coleção Mossoroense                            44         0.0
# Coleção Zila Mamede                            30         0.0
# ...

# %% [markdown]
# A coleçãoo que mais tem emprestimos é a Acervo Circulante apresentando 99%. É bom ter uma atenção para as coleções finais e entender o pq nao esta sendo escolhida pelo publico. Teses e monografias, e afins podem estar disponiveis via plataforma online, podendo ser esse o motivo de nao ter tantos emprestimos.

# %% [markdown]
# ### Quais são as bibliotecas com mais ou menos quantidade de empréstimos?

# %%
tabela_freq('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1426122        68.8
# Biblioteca Setorial do Centro Ciências da Saúde...      118614         5.7
# Biblioteca Setorial da Faculdade de Ciências da...       77609         3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447         3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478         3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040         2.2
# Biblioteca Setorial do Centro de Ciências Human...       40744         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097         1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089         1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219         1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923         1.3
# ...

# %% [markdown]
# #### 2. Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?
# A biblioteca que mais tem exemplares emprestados e a 'Biblioteca Central Zila Mamede', importante verificar se essa biblioteca tem uma localizacao mais acessivel, o tamanho da biblioteca.
#
# Para enriquecer mais a analise e importante avaliar outras metricas, como:
# * Quantidade esperada de emprestimos;
# * Quantidade de emprestimos por usuario cadastrado em cada biblioteca;
# * Acoes e investimentos realizados em cada uma.

# %% [markdown]
# ### De quais temas da CDU são os exemplares emprestados?

# %%
tabela_freq('CDU_categoria')
# Out:
#                                 quantidade  percentual
# CDU_categoria
# Ciencias aplicadas                 1425473        68.8
# Ciencias sociais                    369536        17.8
# Matematica e ciencias neurais        68744         3.3
# Generalidades                        62521         3.0
# Religiao                             62295         3.0
# Filosofia e psicologia               60563         2.9
# Geografia. Biografia. Historia        7989         0.4
# Belas artes                           7911         0.4
# Linguagem                             7490         0.4
# Classe vaga                              0         0.0

# %% [markdown]
# #### 3.Quais são os temas mais emprestados? E os menos?
# De acordo com a tabela da categoria, a categoria que mais aparece é ciencias aplicadas, pode ser por ter o maior público os alunos de graduacao.
#
# A categoria menos emprestada é a de Classe vaga e Linguagem.
#
# Algumas questões surgem:
#
# * O acervo está atualizado?
# * O público da biblioteca tem a necessidade destas informações? Se sim, por que não estão usando?
# * Quais ações de marketing estão sendo realizadas para esses temas?

# %% [markdown]
# # #7DaysOfCode - Python Pandas 5/7: Análise exploratória de dados e Boxplot

# %% [markdown]
# * Avaliar a distribuição de empréstimos mensais por ano dentre os alunos de gradução e pós graduação da coleção que tiver a maior frequência de empréstimos.
# * Plotar um gráfico para cada tipo de usuário. Tenha um boxplot para cada ano e analise o que ocorreu.
#
# * O que está ocorrendo ao decorrer do tempo? Houve algum ano ou anos em específico que te chamaram atenção para alguma diferença? Quais as maiores diferenças entre os empréstimos para os alunos de graduação e pós graduação?

# %% [markdown]
# * Verifique qual é a coleção com maior frequência para cada tipo de usuário.
# * Filtre os dados com condições solicitadas
# * Selecione apenas os empréstimos
# * Faça a contagem de empréstimos mensais por cada ano
# * Crie uma função para gerar a visualização do gráfico de box plot por cada ano.
# * Crie o gráfico de boxplot

# %%
df_completo.head()
# Out:
#    id_emprestimo codigo_barras         data_emprestimo  \
# 0         709684       L095049 2010-01-04 07:44:10.721
# 1         709685       L167050 2010-01-04 07:44:10.750
# 2         709686    2006017618 2010-01-04 08:08:44.081
# 3         709687       L184117 2010-01-04 08:24:21.284
# 4         709688    2007027500 2010-01-04 08:27:33.569
#
#                   data_devolucao matricula_ou_siape    tipo_vinculo_usuario  \
# 0  2010/01/05 16:26:12.662000000       2008023265.0      ALUNO DE GRADUAÇÃO
# 1  2010/01/12 07:34:13.934000000       2008023265.0      ALUNO DE GRADUAÇÃO
# 2  2010/02/25 07:36:25.800000000       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 3  2010/02/03 08:58:45.692000000        200721119.0      ALUNO DE GRADUAÇÃO
# 4  2010/02/03 13:06:30.662000000       2009045971.0      ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao  \
# 0        13259  Acervo Circulante
# 1        70865  Acervo Circulante
# 2       195347  Acervo Circulante
# ...

# %% [markdown]
# ### Alunos de Graduação

# %%
# Verificando qual coleção com maior frequência para alunos de graduação
graduacao = df_completo.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %%
# Filtrar os dados em relação a mês e ano
graduacao_acervo = graduacao.query('colecao == "Acervo Circulante"')
graduacao_acervo = pd.DataFrame(graduacao_acervo)
graduacao_acervo['data_emprestimo'] = pd.to_datetime(graduacao_acervo['data_emprestimo'])
graduacao_acervo['ano'] = graduacao_acervo['data_emprestimo'].dt.year
graduacao_acervo['mes'] = graduacao_acervo['data_emprestimo'].dt.month
graduacao_acervo = graduacao_acervo.loc[:,['ano','mes']]
graduacao_acervo = graduacao_acervo.value_counts().to_frame('quantidade').reset_index()
graduacao_acervo
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %%
# Contagem de empréstimos mensais por cada ano
df_completo['mes_num'] = df_completo['data_emprestimo'].dt.month

dados = df_completo[['tipo_vinculo_usuario','ano_emprestimo','mes_num']]
df = pd.DataFrame(dados)

filtro = df[df['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO']

resultado = filtro.groupby(['ano_emprestimo','mes_num']).size().reset_index(name='quantidade_emprestimos')
print(resultado)
# Out:
#      ano_emprestimo  mes_num  quantidade_emprestimos
# 0              2010        1                    3012
# 1              2010        2                    7807
# 2              2010        3                   15419
# 3              2010        4                   12596
# 4              2010        5                   12320
# ..              ...      ...                     ...
# 118            2019       11                    8887
# 119            2019       12                    2012
# 120            2020        1                    1784
# 121            2020        2                    8162
# 122            2020        3                    8702
#
# [123 rows x 3 columns]

# %%
# Função para gerar boxplot
def gera_box_plot(dataset, x, y, titulo, subtitulo):
    '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''
    
    sns.set_theme(style='darkgrid', palette='Blues', font_scale=1.3)
    plt.figure(figsize=(16,10))

    ax = sns.boxplot(y=y, x=x, data=dataset, color='#4171EF')
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
    
    plt.ylim(0, max(dataset[y])*1.1)
    plt.xlabel(None)
    plt.ylabel(None)
    
    ax.set_title(titulo+'\n', size=20, loc="left", weight='bold')
    ax.text(s=subtitulo, x=-0.5, y=max(dataset[y])*1.11, fontsize=18, ha='left', color='gray')

# %%
gera_box_plot(graduacao_acervo, 'ano', 'quantidade', 'Distribuicao dos emprestimos mensais', 'Realizados pelos alunos de graduacao do acervo circulante')

# %% [markdown]
# É possível observar com os dados de 2010 a 2020 que teve uma oscilação significativa da quantidade de empréstimos ao longo dos anos.
#
# Os anos de 2014 e 2017 chamam a atenção, se tirarmos os outliers (provavelmente os meses de janeiro e fevereiro com poucos emprestimos) teríamos anos com uma quantidade constante de empréstimos mensais. Porém, 2014 teve um declínio e 2017 um aumento em relação aos anos anteriores.
#
# Seria interessante entender com a direção das bibliotecas o que ocorreu nessas datas para que pudéssemos ter um contexto melhor da realidade do negócio.

# %% [markdown]
# ### Alunos de Pós Graduação

# %%
# Verificando qual coleção com maior frequência para alunos de graduação
pos_graduacao = df_completo.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
pos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: count, dtype: int64

# %%
# Filtrar os dados em relação a mês e ano
pos_graduacao_acervo = pos_graduacao.query('colecao == "Acervo Circulante"')
pos_graduacao_acervo = pd.DataFrame(pos_graduacao_acervo)
pos_graduacao_acervo['data_emprestimo'] = pd.to_datetime(pos_graduacao_acervo['data_emprestimo'])
pos_graduacao_acervo['ano'] = pos_graduacao_acervo['data_emprestimo'].dt.year
pos_graduacao_acervo['mes'] = pos_graduacao_acervo['data_emprestimo'].dt.month
pos_graduacao_acervo = pos_graduacao_acervo.loc[:,['ano','mes']]
pos_graduacao_acervo = pos_graduacao_acervo.value_counts().to_frame('quantidade').reset_index()
pos_graduacao_acervo
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %%
# Contagem de empréstimos mensais por cada ano
df_completo['mes_num'] = df_completo['data_emprestimo'].dt.month

dados = df_completo[['tipo_vinculo_usuario','ano_emprestimo','mes_num']]
df = pd.DataFrame(dados)

filtro = df[df['tipo_vinculo_usuario'] == 'ALUNO DE PÓS-GRADUAÇÃO']

resultado = filtro.groupby(['ano_emprestimo','mes_num']).size().reset_index(name='quantidade_emprestimos')
print(resultado)
# Out:
#      ano_emprestimo  mes_num  quantidade_emprestimos
# 0              2010        1                    1125
# 1              2010        2                    1508
# 2              2010        3                    2972
# 3              2010        4                    2774
# 4              2010        5                    2563
# ..              ...      ...                     ...
# 119            2019       12                    1078
# 120            2020        1                    1148
# 121            2020        2                    1200
# 122            2020        3                    1483
# 123            2020        6                       2
#
# [124 rows x 3 columns]

# %%
gera_box_plot(pos_graduacao_acervo, 'ano', 'quantidade', 'Distribuicao dos emprestimos mensais', 'Realizados pelos alunos de pós graduacao do acervo circulante')

# %% [markdown]
# Já os alunos de pós graduação tiveram um aspecto diferente em relação ao declínio a partir de 2013:
#
# A linha mediana foi diminuindo devagar até 2018. Entretanto valores máximos foram superiores, apenas caindo de fato em 2019.
# Nos dois gráficos podemos observar um grande aumento entre 2010 e 2013, o que nos leva a pensar em quais procedimentos estavam sendo realizados neste período para que houvesse esse crescimento.
#
# Nos dois anos recortes visualizamos que a partir de 2018 tivemos um forte declínio e é um alerta para que a direção possa entender o que está ocorrendo.

# %% [markdown]
# # #7DaysOfCode - Python Pandas 6/7: JSON, Excel e Pivot_table

# %%
# !pip install --upgrade pandas

# %%
# !pip install --upgrade openpyxl --user

# %%
# Extrais os arquivos do excel
cadastro_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx', sheet_name='Até 2010', skiprows=1)

cadastro_pos_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx', sheet_name='Após 2010', skiprows=1)

# %% [markdown]
# ### Cadastros de 2010

# %%
# Informações sobre a tabela
cadastro_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7726 entries, 0 to 7725
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número da matrícula  7726 non-null   float64
#  1   Tipo de vinculo      7726 non-null   object
#  2   Curso                7726 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 181.2+ KB

# %%
# Renomear as colunas para linkar com a tabela anterior
cadastro_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
# Visualizar as 5 primeiras linhas
cadastro_2010
# Out:
#       matricula_ou_siape tipo_vinculo_usuario  \
# 0           1.900017e+08   ALUNO DE GRADUAÇÃO
# 1           1.990145e+08   ALUNO DE GRADUAÇÃO
# 2           1.997357e+08   ALUNO DE GRADUAÇÃO
# 3           1.998124e+08   ALUNO DE GRADUAÇÃO
# 4           1.998237e+08   ALUNO DE GRADUAÇÃO
# ...                  ...                  ...
# 7721        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7722        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7723        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7724        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7725        2.009075e+09   ALUNO DE GRADUAÇÃO
#
#                                       curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %% [markdown]
# ### Cadastros de 2010 em diante

# %%
# Informações sobre a tabela após 2010
cadastro_pos_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2274 entries, 0 to 2273
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Matricula        2274 non-null   float64
#  1   Tipo de vinculo  2274 non-null   object
#  2   Cursos           2274 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 53.4+ KB

# %%
# Renomear as colunas para linkar com a tabela anterior
cadastro_pos_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
# Visualizar as 5 primeiras linhas
cadastro_pos_2010
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           2.010000e+09   ALUNO DE GRADUAÇÃO                   DIREITO
# 1           2.010000e+09   ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2           2.010001e+09   ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3           2.010003e+09   ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4           2.010003e+09   ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...                  ...                  ...                       ...
# 2269        2.015012e+10   ALUNO DE GRADUAÇÃO                    LETRAS
# 2270        2.015075e+09   ALUNO DE GRADUAÇÃO                     DANÇA
# 2271        2.016000e+10   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272        2.017009e+10   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273        2.018009e+10   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %% [markdown]
# ### Unir as tabelas

# %%
# Juntar as tabelas
df_cadastro = pd.concat([cadastro_2010,cadastro_pos_2010], ignore_index=True)
df_cadastro.matricula_ou_siape = df_cadastro.matricula_ou_siape.astype(str)
df_cadastro
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Ler banco de dados JSON

# %%
url = 'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json'

df_json = pd.read_json(url)

df_json.head()
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
# Organizando a tabela
cadastro_json = pd.read_json(df_json.registros[0])
cadastro_json
# Out:
# C:\Users\Izabella\AppData\Local\Temp\ipykernel_21316\2262624261.py:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   cadastro_json = pd.read_json(df_json.registros[0])
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# ...

# %%
# Visualizar as 5 primeiras linhas
cadastro_json.head()
# Out:
#    matricula_ou_siape tipo_vinculo_usuario                   curso
# 0          2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1           200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2           200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3           200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4           200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO

# %%
# Informações sobre a tabela
cadastro_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  int64
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
# Modificar o tipo de dados
cadastro_json.matricula_ou_siape = cadastro_json.matricula_ou_siape.astype('float')
cadastro_json.matricula_ou_siape = cadastro_json.matricula_ou_siape.astype('string')
cadastro_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Unir as tabelas Excel e JSON

# %%
# Concatenando arquivos Excel e Json
df_cadastro = pd.concat([df_cadastro,cadastro_json], ignore_index=True)
df_cadastro
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0            190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1            199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2            199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3            199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4            199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798      20200039601.0   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799      20200132517.0   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %%
# Quantidade de emprestimos de 2015 em diante 
emprestimos_pos_2015 = df_completo.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
emprestimos_pos_2015 = emprestimos_pos_2015.loc[:,['matricula_ou_siape', 'data_emprestimo']]
emprestimos_pos_2015 = emprestimos_pos_2015.query('data_emprestimo > 2015')
emprestimos_pos_2015 = emprestimos_pos_2015.reset_index(drop=True)
emprestimos_pos_2015
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013021576.0 2015-01-02 09:16:49.566
# 1            2014026648.0 2015-01-02 09:44:42.808
# 2            2014026648.0 2015-01-02 09:44:43.127
# 3            2010049586.0 2015-01-02 10:11:09.837
# 4            2014021454.0 2015-01-02 10:19:38.087
# ...                   ...                     ...
# 788099      20190154579.0 2020-03-18 16:26:20.477
# 788100      20160129109.0 2020-03-18 16:41:28.500
# 788101      20160129109.0 2020-03-18 16:41:28.588
# 788102      20160129109.0 2020-03-18 16:41:28.662
# 788103      20160129109.0 2020-03-18 16:41:28.713
#
# [788104 rows x 2 columns]

# %%
# Verificar se há valores nulos
emprestimos_pos_2015.isnull().sum()
# Out:
# matricula_ou_siape    0
# data_emprestimo       0
# dtype: int64

# %%
# Filtrar cursos selecionados

cadastro_cursos_selecionados = df_cadastro.query("curso == ['BIBLIOTECONOMIA','CIÊNCIAS SOCIAIS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']")
cadastro_cursos_selecionados
# Out:
#       matricula_ou_siape tipo_vinculo_usuario             curso
# 8            200031011.0   ALUNO DE GRADUAÇÃO           DIREITO
# 9            200045080.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15           200115053.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18           200123382.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19           200123730.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...                  ...                  ...               ...
# 72789      20200097481.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72796      20200107087.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO           DIREITO
#
# [18833 rows x 3 columns]

# %% [markdown]
# ### Unir DataFrame de cadastro de usuário com o de empréstimos

# %%
# Unir DataFrame de cadastro de usuário com o de empréstimos
cadastro_cursos_selecionados = emprestimos_pos_2015.merge(cadastro_cursos_selecionados)
cadastro_cursos_selecionados
# Out:
#        matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0            2014021454.0 2015-01-02 10:19:38.087   ALUNO DE GRADUAÇÃO
# 1            2013018187.0 2015-01-02 10:25:40.883   ALUNO DE GRADUAÇÃO
# 2            2014029499.0 2015-01-02 12:26:43.571   ALUNO DE GRADUAÇÃO
# 3            2014029499.0 2015-01-02 12:26:43.840   ALUNO DE GRADUAÇÃO
# 4            2014029499.0 2015-01-02 12:26:44.750   ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                  ...
# 212833      20200090284.0 2020-03-17 20:23:54.966   ALUNO DE GRADUAÇÃO
# 212834      20180113385.0 2020-03-17 21:20:47.278   ALUNO DE GRADUAÇÃO
# 212835      20190150079.0 2020-03-18 13:43:53.220   ALUNO DE GRADUAÇÃO
# 212836      20190150079.0 2020-03-18 13:43:53.389   ALUNO DE GRADUAÇÃO
# 212837      20190150079.0 2020-03-18 13:43:53.456   ALUNO DE GRADUAÇÃO
#
#                    curso
# 0              FILOSOFIA
# 1                DIREITO
# 2       CIÊNCIAS SOCIAIS
# ...

# %%
# Criação de uma tabela com ano, curso e quantidade de emprestimos

cadastro_cursos_selecionados.data_emprestimo = cadastro_cursos_selecionados.data_emprestimo.dt.year

emprestimos_cursos_selecionados = cadastro_cursos_selecionados.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_cursos_selecionados.columns = ['ANO', 'CURSO', 'QUANTIDADE_EMPRESTIMOS']
emprestimos_cursos_selecionados
# Out:
#      ANO               CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017  COMUNICAÇÃO SOCIAL                    8253
# 1   2016  COMUNICAÇÃO SOCIAL                    7973
# 2   2017             DIREITO                    7885
# 3   2015     BIBLIOTECONOMIA                    7784
# 4   2015             DIREITO                    7665
# 5   2016           FILOSOFIA                    7576
# 6   2015    CIÊNCIAS SOCIAIS                    7489
# 7   2017           PEDAGOGIA                    7434
# 8   2017           FILOSOFIA                    7389
# 9   2016             DIREITO                    7363
# 10  2017     BIBLIOTECONOMIA                    7307
# 11  2015           PEDAGOGIA                    7189
# 12  2016           PEDAGOGIA                    7153
# 13  2015  COMUNICAÇÃO SOCIAL                    7147
# 14  2016     BIBLIOTECONOMIA                    7044
# 15  2018             DIREITO                    7027
# 16  2016    CIÊNCIAS SOCIAIS                    6978
# ...

# %% [markdown]
# ### Tabela Pivotada

# %% [markdown]
# ##### Gere uma tabela com as seguintes características:
#
#
# * Índice: Cursos
# * Colunas: Ano
# * Valores: Quantidade de empréstimos
# * Total: Acrescente uma linha e uma coluna de total a tabela

# %%
emprestimos_pivot = emprestimos_cursos_selecionados.pivot_table(
    index = 'CURSO',
    columns = 'ANO',
    values = 'QUANTIDADE_EMPRESTIMOS',
    fill_value = '-',
    aggfunc = sum,
    margins = True,
    margins_name = 'TOTAL',
)

emprestimos_pivot
# Out:
# C:\Users\Izabella\AppData\Local\Temp\ipykernel_21316\1430892194.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   emprestimos_pivot = emprestimos_cursos_selecionados.pivot_table(
# C:\Users\Izabella\AppData\Local\Temp\ipykernel_21316\1430892194.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   emprestimos_pivot = emprestimos_cursos_selecionados.pivot_table(
# ...

# %% [markdown]
# # #7DaysOfCode - Python Pandas 7/7: Customização de tabelas

# %% [markdown]
# * Analisar a diferença percentual de empréstimos realizados nos últimos anos (2017, 2018, 2019) para cada curso
# * Análise de previsão de empréstimos de 2022
# * Criar uma tabela com as diferenças percentuais de empréstimos entre 2017-2018, 2018-2019, 2019-2022
# * Enviar a tabela em HTML com as seguintes características:
#     * Não contenha numeração de índice;
#     * Os nomes dos cursos tenham apenas a primeira letra maiúscula;
#     * Os números percentuais estejam indicados pelo símbolo “%”;
#     * Cor dos números: Positivos = Verde; Negativos = Vermelho

# %% [markdown]
# ### Importar bancos de dados

# %%
cadastro_antes_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_depois_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %% [markdown]
# ### Visualizar o banco de dados antes de 2010

# %%
cadastro_antes_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %% [markdown]
# ### Visualizar o banco de dados apos de 2010

# %%
cadastro_depois_2010
# Out:
#         Matricula      Tipo de vinculo                    Cursos
# 0     2.010000e+09  ALUNO DE GRADUAÇÃO                   DIREITO
# 1     2.010000e+09  ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2     2.010001e+09  ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3     2.010003e+09  ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4     2.010003e+09  ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...            ...                 ...                       ...
# 2269  2.015012e+10  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270  2.015075e+09  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  2.016000e+10  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  2.017009e+10  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  2.018009e+10  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %% [markdown]
# ### Modificar as colunas para mesclar as tabelas

# %%
cadastro_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %% [markdown]
# ### Concatenar as tabelas

# %%
cadastro_usuarios_excel = pd.concat([cadastro_antes_2010,cadastro_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
cadastro_usuarios_excel
# Out:
#       Número da matrícula     Tipo de vinculo                Curso  \
# 0             190001688.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1             199014489.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2             199735674.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3             199812431.0  ALUNO DE GRADUAÇÃO               LETRAS
# 4             199823670.0  ALUNO DE GRADUAÇÃO             ECOLOGIA
# ...                   ...                 ...                  ...
# 9995                  NaN                 NaN                  NaN
# 9996                  NaN                 NaN                  NaN
# 9997                  NaN                 NaN                  NaN
# 9998                  NaN                 NaN                  NaN
# 9999                  NaN                 NaN                  NaN
#
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0                  <NA>                  NaN                       NaN
# ...

# %% [markdown]
# ### Importar banco de dados JSON

# %%
cadastro_json = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
cadastro_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %% [markdown]
# ### Selecionar o segundo indice para pegar somente os dados dos alunos de Pos Graduacao

# %%
cadastro_posgraduacao_json = pd.read_json(cadastro_json.registros[1])
# Out:
# C:\Users\Izabella\AppData\Local\Temp\ipykernel_21316\4111133302.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   cadastro_posgraduacao_json = pd.read_json(cadastro_json.registros[1])

# %%
cadastro_posgraduacao_json
# Out:
#        matricula_ou_siape    tipo_vinculo_usuario  \
# 0              2008112114  ALUNO DE PÓS-GRADUAÇÃO
# 1              2008106583  ALUNO DE PÓS-GRADUAÇÃO
# 2              2011101417  ALUNO DE PÓS-GRADUAÇÃO
# 3              2011113122  ALUNO DE PÓS-GRADUAÇÃO
# 4              2010110903  ALUNO DE PÓS-GRADUAÇÃO
# ...                   ...                     ...
# 19435         20201013501  ALUNO DE PÓS-GRADUAÇÃO
# 19436         20201014062  ALUNO DE PÓS-GRADUAÇÃO
# 19437         20201017690  ALUNO DE PÓS-GRADUAÇÃO
# 19438         20201014465  ALUNO DE PÓS-GRADUAÇÃO
# 19439         20201014993  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# ...

# %%
cadastro_posgraduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    19440 non-null  int64
#  1   tipo_vinculo_usuario  19440 non-null  object
#  2   curso                 19440 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 455.8+ KB

# %% [markdown]
# ### Modificar o tipo de dado

# %%
cadastro_posgraduacao_json.matricula_ou_siape = cadastro_posgraduacao_json.matricula_ou_siape.astype('float')
cadastro_posgraduacao_json.matricula_ou_siape = cadastro_posgraduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_posgraduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    19440 non-null  string
#  1   tipo_vinculo_usuario  19440 non-null  object
#  2   curso                 19440 non-null  object
# dtypes: object(2), string(1)
# memory usage: 455.8+ KB

# %% [markdown]
# ### Concatenar Excel e JSON

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_posgraduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#        Número da matrícula     Tipo de vinculo                Curso  \
# 0              190001688.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1              199014489.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2              199735674.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3              199812431.0  ALUNO DE GRADUAÇÃO               LETRAS
# 4              199823670.0  ALUNO DE GRADUAÇÃO             ECOLOGIA
# ...                    ...                 ...                  ...
# 29435                  NaN                 NaN                  NaN
# 29436                  NaN                 NaN                  NaN
# 29437                  NaN                 NaN                  NaN
# 29438                  NaN                 NaN                  NaN
# 29439                  NaN                 NaN                  NaN
#
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0                   <NA>                     NaN
# ...

# %% [markdown]
# ### Selecionar somente os dados de alunos de Pos Graduacao

# %%
cadastro_pos_graduacao_cursos = cadastro_posgraduacao_json.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
cadastro_pos_graduacao_cursos
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0           2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 1           2008106583.0  ALUNO DE PÓS-GRADUAÇÃO
# 2           2011101417.0  ALUNO DE PÓS-GRADUAÇÃO
# 3           2011113122.0  ALUNO DE PÓS-GRADUAÇÃO
# 4           2010110903.0  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...
# 19435      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 19436      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 19437      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 19438      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 19439      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# ...

# %% [markdown]
# ### Filtrar emprestimos desde 2017

# %%
emprestimo_2017 = df_completo.loc[:,['matricula_ou_siape','data_emprestimo']]
emprestimo_2017 = emprestimo_2017.query('data_emprestimo > 2017')
emprestimo_2017 = emprestimo_2017.reset_index(drop=True)
emprestimo_2017
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2014035816.0 2017-01-02 08:01:14.113
# 1           20161011168.0 2017-01-02 08:29:46.722
# 2           20161011168.0 2017-01-02 08:29:46.794
# 3           20161011168.0 2017-01-02 08:46:42.991
# 4           20161011168.0 2017-01-02 08:46:43.400
# ...                   ...                     ...
# 609948          3067431.0 2020-05-05 19:51:06.059
# 609949          3067431.0 2020-05-05 19:51:06.135
# 609950          3067431.0 2020-05-05 19:51:06.164
# 609951      20201014993.0 2020-06-09 11:54:02.669
# 609952      20201014993.0 2020-06-09 11:54:02.852
#
# [609953 rows x 2 columns]

# %% [markdown]
# ### Unindo df de cadastro de usuarios e de emprestimos

# %%
emprestimo_desde_2017 = emprestimo_2017.merge(cadastro_pos_graduacao_cursos)
emprestimo_desde_2017
# Out:
#       matricula_ou_siape         data_emprestimo    tipo_vinculo_usuario  \
# 0          20161011168.0 2017-01-02 08:29:46.722  ALUNO DE PÓS-GRADUAÇÃO
# 1          20161011168.0 2017-01-02 08:29:46.794  ALUNO DE PÓS-GRADUAÇÃO
# 2          20161011168.0 2017-01-02 08:46:42.991  ALUNO DE PÓS-GRADUAÇÃO
# 3          20161011168.0 2017-01-02 08:46:43.400  ALUNO DE PÓS-GRADUAÇÃO
# 4          20161013903.0 2017-01-02 09:41:45.823  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...                     ...
# 92057      20191017055.0 2020-03-19 14:41:57.754  ALUNO DE PÓS-GRADUAÇÃO
# 92058      20191017055.0 2020-03-19 14:42:56.670  ALUNO DE PÓS-GRADUAÇÃO
# 92059      20191017055.0 2020-03-19 14:43:40.666  ALUNO DE PÓS-GRADUAÇÃO
# 92060      20201014993.0 2020-06-09 11:54:02.669  ALUNO DE PÓS-GRADUAÇÃO
# 92061      20201014993.0 2020-06-09 11:54:02.852  ALUNO DE PÓS-GRADUAÇÃO
#
#                   curso
# 0             FILOSOFIA
# 1             FILOSOFIA
# ...

# %% [markdown]
# ### Modificando o tipo de data

# %%
emprestimo_desde_2017.data_emprestimo = emprestimo_desde_2017.data_emprestimo.dt.year

# %% [markdown]
# ### Contando valores de emprestimos

# %%
emprestimo_desde_2017 = emprestimo_desde_2017.iloc[:,[1,3]].value_counts().reset_index()
emprestimo_desde_2017.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimo_desde_2017.head()
# Out:
#     ANO                           CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2018          CIÊNCIAS ODONTOLÓGICAS                    2540
# 1  2017                   ADMINISTRAÇÃO                    2538
# 2  2017          ENGENHARIA DE SOFTWARE                    2477
# 3  2017               CIÊNCIAS DA SAÚDE                    2434
# 4  2017  CIÊNCIA, TECNOLOGIA E INOVAÇÃO                    2415

# %% [markdown]
# ### Pivotando tabela

# %%
emprestimo_desde_2017_pivot = emprestimo_desde_2017.pivot_table(
    index = 'CURSO',
    columns = 'ANO',
    values = 'QUANTIDADE_EMPRESTIMOS',
    fill_value = '-',
)

emprestimo_desde_2017_pivot
# Out:
# ANO                                       2017    2018    2019   2020
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0
# DESIGN                                  2272.0  1838.0  1841.0  254.0
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0
# ENGENHARIA DE SOFTWARE                  2477.0  2222.0  1887.0  264.0
# ...

# %% [markdown]
# ### Importando dados de previsao

# %%
previsao_2022 = pd.read_table('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_7-Apresentando_resultados_em_HTML/Dataset/previsao')

# %%
previsao_2022
# Out:
#                             curso previsao_2022
# 0                            administracao 1905
# 1                  arquitetura_e_urbanismo 1896
# 2                            artes_cenicas 1920
# 3                           bioinformatica 2302
# 4                               bioquimica 2090
# 5        ciencia_e_engenharia_de_materiais 2010
# 6            ciencia_tecnologia_e_inovacao 1960
# 7                        ciencias_da_saude 1730
# 8                   ciencias_odontologicas 2405
# 9                                   design 1900
# 10                        engenharia_civil 1920
# 11                     engenharia_software 1890
# 12                               filosofia 1903
# 13  gestao_da_informacao_e_do_conhecimento 1855

# %% [markdown]
# ### Tratando dados da previsao

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)

# %% [markdown]
# ### Unindo as tabelas

# %%
previsao_2022.index = emprestimo_desde_2017_pivot.index
emprestimo_desde_2017_pivot['2022'] = previsao_2022.iloc[:,1]
emprestimo_desde_2017_pivot
# Out:
# ANO                                       2017    2018    2019   2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0  1905
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0  1896
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0  1920
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0  2302
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0  1960
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0  2405
# DESIGN                                  2272.0  1838.0  1841.0  254.0  1900
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0  1920
# ...

# %% [markdown]
# ### Modificando o tipo de dado

# %%
emprestimo_desde_2017_pivot['2022'] = emprestimo_desde_2017_pivot['2022'].astype('int')

# %% [markdown]
# ### Pivotando tabela

# %%
emprestimo_desde_2017_pivot
# Out:
# ANO                                       2017    2018    2019   2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0  1905
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0  1896
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0  1920
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0  2302
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0  1960
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0  2405
# DESIGN                                  2272.0  1838.0  1841.0  254.0  1900
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0  1920
# ...

# %% [markdown]
# ### Criando funcao para diferenca percentual

# %%
def dif_percentual(x,y):
    return round(((x/y * 100) - 100), 2)

# %% [markdown]
# ### Calculando a diferenca percentual

# %%
percentual_2018 = dif_percentual(emprestimo_desde_2017_pivot.iloc[:, 1], emprestimo_desde_2017_pivot.iloc[:, 0])
percentual_2019 = dif_percentual(emprestimo_desde_2017_pivot.iloc[:, 2], emprestimo_desde_2017_pivot.iloc[:, 1])
percentual_2022 = dif_percentual(emprestimo_desde_2017_pivot.iloc[:, 3], emprestimo_desde_2017_pivot.iloc[:, 2])

# %% [markdown]
# ### Criando df com as diferencas percentuais

# %%
percentual_table = pd.DataFrame({'2018':percentual_2018,
                                '2019':percentual_2019,
                                '2022':percentual_2022})
percentual_table
# Out:
#                                          2018   2019   2022
# CURSO
# ADMINISTRAÇÃO                           -8.75 -26.94 -84.10
# ARQUITETURA E URBANISMO                -13.22  -5.16 -85.86
# ARTES CÊNICAS                           -1.56 -12.97 -87.36
# BIOINFORMÁTICA                         -12.60  -4.65 -85.59
# BIOQUÍMICA                             -15.26   5.81 -86.78
# CIÊNCIA E ENGENHARIA DE MATERIAIS       -8.89  -4.83 -83.67
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          -2.07 -14.33 -85.04
# CIÊNCIAS DA SAÚDE                      -18.41  -8.11 -87.18
# CIÊNCIAS ODONTOLÓGICAS                   5.22 -15.98 -83.51
# DESIGN                                 -19.10   0.16 -86.20
# ENGENHARIA CIVIL                       -12.92  -4.79 -87.23
# ENGENHARIA DE SOFTWARE                 -10.29 -15.08 -86.01
# FILOSOFIA                               -5.62 -13.43 -82.97
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -16.55  -6.35 -85.77

# %% [markdown]
# ### Formatando dados da tabela

# %%
percentual_table.reset_index(inplace=True)
percentual_table.columns = percentual_table.columns.str.capitalize()
percentual_table.Curso = percentual_table.Curso.str.capitalize()

percentual_table
# Out:
#                                      Curso   2018   2019   2022
# 0                            Administração  -8.75 -26.94 -84.10
# 1                  Arquitetura e urbanismo -13.22  -5.16 -85.86
# 2                            Artes cênicas  -1.56 -12.97 -87.36
# 3                           Bioinformática -12.60  -4.65 -85.59
# 4                               Bioquímica -15.26   5.81 -86.78
# 5        Ciência e engenharia de materiais  -8.89  -4.83 -83.67
# 6           Ciência, tecnologia e inovação  -2.07 -14.33 -85.04
# 7                        Ciências da saúde -18.41  -8.11 -87.18
# 8                   Ciências odontológicas   5.22 -15.98 -83.51
# 9                                   Design -19.10   0.16 -86.20
# 10                        Engenharia civil -12.92  -4.79 -87.23
# 11                  Engenharia de software -10.29 -15.08 -86.01
# 12                               Filosofia  -5.62 -13.43 -82.97
# 13  Gestão da informação e do conhecimento -16.55  -6.35 -85.77

# %% [markdown]
# ### Criando tabela em HTML

# %% [markdown]
# ### Estruturando formatacao da tabela em CSS

# %%
styles = [
    dict(selector='th', props=[
                                ('font-size', '1.4rem'),
                                ('text-align', 'center'),
                                ('font-weight', 'bold'),
                                ('color', 'white'),
                                ('background-color', '#001692'),
                                ('border-radius', '0.25rem'),
                                ('box-shadow', '0 0 1rem gray')
                                ]),
    dict(selector='th', props=[
                                ('font-size', '1rem'),
                                ('padding', '0.5rem'),
                                ('text-align', 'left'),
                                ('font-weight', 'bold'),
                                ('border-bottom', '0.1rem solid lightgray'),
                                ])
]

# %% [markdown]
# ### Gerando tabela HTML

# %%
percentual_table.style.background_gradient(cmap='RdYlGn', low=1, axis=1, vmax=0.1, vmin=0)\
                                           .format('{:.2f} %', subset=['2018', '2019', '2022'])\
                                           .set_table_styles(styles)\
                                           .to_html('teste.html', doctype_html=True,
                                                   table_attributes = 'ALIGN=LEFT WIDTH=50% CELLSPACING = 5')
